# %%
library(openintro)

# %%
names(county)
# Out:
#  [1] "name"              "state"             "pop2000"
#  [4] "pop2010"           "pop2017"           "pop_change"
#  [7] "poverty"           "homeownership"     "multi_unit"
# [10] "unemployment_rate" "metro"             "median_edu"
# [13] "per_capita_income" "median_hh_income"  "smoking_ban"

# %%
hist(county$pop2017)
# Out:
# Plot with title "Histogram of county$pop2017"

# %%
hist(log(county$pop2017))
# Out:
# Plot with title "Histogram of log(county$pop2017)"

# %%
plot(county$pop2010, county$pop_change)
# Out:
# plot without title

# %%
plot(log(county$pop2010), log(county$pop_change))
# Out:
# Warning message in log(county$pop_change):
# "NaNs produced"
# plot without title
