# %%
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
sample = [67, 66, 67, 65, 66, 69, 65, 67, 64, 66, 67,
70, 72, 67, 66, 73, 69, 66, 68, 69]
df = pd.DataFrame(sample)
df.columns = ['age']

# %%
df.head()
# Out:
#    age
# 0   67
# 1   66
# 2   67
# 3   65
# 4   66

# %%
from scipy.stats import norm
sns.distplot(df.age,fit=norm)
df.describe().T
# Out:
#      count   mean       std   min   25%   50%   75%   max
# age   20.0  67.45  2.305029  64.0  66.0  67.0  69.0  73.0

# %%
import math
import numpy as np
from scipy import stats
#mu=70
#sigma = 15/math.sqrt(30)
#x = np.linspace(mu-3*sigma,mu+3*sigma,100)
#plt.plot(x, stats.norm.pdf(x, mu, sigma))
sampling_dist = np.random.normal(70,15/np.sqrt(30),100000)
sns.distplot(sampling_dist)
sns.distplot(df.age)
plt.axvline(mu)
plt.axvline(df.age.mean())

# %%
import scipy.stats as st
from pprint import pprint
pprint(st.describe(df.age))
# Out:
# DescribeResult(nobs=20, minmax=(64, 73), mean=67.45, variance=5.313157894736842, skewness=0.9122324316024498, kurtosis=0.28354554466593607)

# %%
st.probplot(df.age,plot=plt)
# Out:
# ((array([-1.8241636 , -1.38768012, -1.11829229, -0.91222575, -0.73908135,
#          -0.5857176 , -0.44506467, -0.31273668, -0.18568928, -0.06158146,
#           0.06158146,  0.18568928,  0.31273668,  0.44506467,  0.5857176 ,
#           0.73908135,  0.91222575,  1.11829229,  1.38768012,  1.8241636 ]),
#   array([64, 65, 65, 66, 66, 66, 66, 66, 67, 67, 67, 67, 67, 68, 69, 69, 69,
#          70, 72, 73], dtype=int64)),
#  (2.3153786183009695, 67.45, 0.9534682494106835))

# %%
sigma = 15/np.sqrt(30)
hnot = np.random.normal(67,sigma,100000)
halter = np.random.normal(70,sigma,100000) 
hother = np.random.normal(71,sigma,100000)
sns.distplot(hnot)
sns.distplot(halter)
sns.distplot(hother)
plt.axvline(73)
