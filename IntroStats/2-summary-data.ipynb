# %%
library(openintro)

# %% [markdown]
# # Numerical Data

# %%
# Scatter plot and Regression Line
plot(loan50$total_income, loan50$loan_amount)
l = lm(loan50$loan_amount ~ loan50$total_income)
abline(l)
# Out:
# plot without title

# %%
# Histogram
hist(loan50$interest_rate, breaks=8)
# Out:
# Plot with title "Histogram of loan50$interest_rate"

# %%
# Summary (Descriptive Statistics)
summary(loan50$interest_rate)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    5.31    7.96    9.93   11.57   13.71   26.30

# %%
cat("Sdev\tIQR\n")
cat(sd(loan50$interest_rate), IQR(loan50$interest_rate))
# Out:
# Sdev	IQR
# 5.052115 5.755

# %%
# Box-Whisker Plot
boxplot(loan50$interest_rate)
# Out:
# plot without title

# %%
hist(loan50$loan_amount,breaks=13)
# Out:
# Plot with title "Histogram of loan50$loan_amount"

# %%
boxplot(loan50$loan_amount)
# Out:
# plot without title

# %%
cat(sd(loan50$loan_amount), IQR(loan50$loan_amount))
# Out:
# 10455.46 16875

# %%
summary(loan50$loan_amount)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    3000    7125   15500   17083   24000   40000

# %% [markdown]
# # Categorical Data

# %%
data <- loans_full_schema
sort(names(data))
# Out:
#  [1] "account_never_delinq_percent"     "accounts_opened_24m"
#  [3] "annual_income"                    "annual_income_joint"
#  [5] "application_type"                 "balance"
#  [7] "current_accounts_delinq"          "current_installment_accounts"
#  [9] "debt_to_income"                   "debt_to_income_joint"
# [11] "delinq_2y"                        "disbursement_method"
# [13] "earliest_credit_line"             "emp_length"
# [15] "emp_title"                        "grade"
# [17] "homeownership"                    "initial_listing_status"
# [19] "inquiries_last_12m"               "installment"
# [21] "interest_rate"                    "issue_month"
# [23] "loan_amount"                      "loan_purpose"
# [25] "loan_status"                      "months_since_90d_late"
# [27] "months_since_last_credit_inquiry" "months_since_last_delinq"
# [29] "num_accounts_120d_past_due"       "num_accounts_30d_past_due"
# [31] "num_active_debit_accounts"        "num_cc_carrying_balance"
# ...

# %%
T = table(data$application_type, data$homeownership)
t = table(data$homeownership)
T
# Out:
#
#                    ANY MORTGAGE  OWN RENT
#                 0    0        0    0    0
#   individual    0    0     3839 1170 3496
#   joint         0    0      950  183  362

# %%
plot(data$homeownership)
# Out:
# plot without title

# %%
unique(data$homeownership)
# Out:
# [1] MORTGAGE RENT     OWN
# Levels:  ANY MORTGAGE OWN RENT

# %%
boxplot(data$loan_amount ~ data$application_type)
# Out:
# plot without title

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
sort(names(iris))
# Out:
# [1] "Petal.Length" "Petal.Width"  "Sepal.Length" "Sepal.Width"  "Species"

# %%
boxplot(iris$Sepal.Length ~ iris$Species)
# Out:
# plot without title
