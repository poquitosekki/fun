# %%
library(dplyr)
library(ggplot2)
library(nycflights13)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
head(nycflights13::flights)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
dim(flights)
# Out:
# [1] 336776     19

# %% [markdown]
# ## Core of dplyr
#
# The five key dplyr functions to solve the majority of data manipulation challenges:
# * filter()     : pick observations by their values
# * arrange()   : reorder the rows
# * select()    : pick variables by their names
# * mutate()    : create new variables using existing ones
# * summarise() : collapse many values to a single summary

# %%
names(flights)
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %% [markdown]
# ## Operations on Rows (filter, arrange)

# %%
jan1 <- filter(flights,month==1,day==1)
head(jan1)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
dec25 <- filter(flights,month==12,day==25)
head(dec25)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 12    25  456      500            -4         649      651
# 2 2013 12    25  524      515             9         805      814
# 3 2013 12    25  542      540             2         832      850
# 4 2013 12    25  546      550            -4        1022     1027
# 5 2013 12    25  556      600            -4         730      745
# 6 2013 12    25  557      600            -3         743      752
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  -2       US      1895   N156UW  EWR    CLT   98       529     5     0
# 2  -9       UA      1016   N32404  EWR    IAH  203      1400     5    15
# 3 -18       AA      2243   N5EBAA  JFK    MIA  146      1089     5    40
# 4  -5       B6       939   N665JB  JFK    BQN  191      1576     5    50
# 5 -15       AA       301   N3JLAA  LGA    ORD  123       733     6     0
# ...

# %%
filter(flights,arr_delay>=2)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   554      558            -4         740      728
# 5      2013 1     1   555      600            -5         913      854
# 6      2013 1     1   558      600            -2         753      745
# 7      2013 1     1   558      600            -2         924      917
# 8      2013 1     1   559      600            -1         941      910
# 9      2013 1     1   600      600             0         837      825
# 10     2013 1     1   602      605            -3         821      805
# 11     2013 1     1   608      600             8         807      735
# 12     2013 1     1   611      600            11         945      931
# ...

# %%
filter(flights,dest %in% c('IAH','HOU'))
filter(flights,dest=='IAH'|dest=='HOU')
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1    2013 1     1    517      515             2        830      819
# 2    2013 1     1    533      529             4        850      830
# 3    2013 1     1    623      627            -4        933      932
# 4    2013 1     1    728      732            -4       1041     1038
# 5    2013 1     1    739      739             0       1104     1038
# 6    2013 1     1    908      908             0       1228     1219
# 7    2013 1     1   1028     1026             2       1350     1339
# 8    2013 1     1   1044     1045            -1       1352     1351
# 9    2013 1     1   1114      900           134       1447     1222
# 10   2013 1     1   1205     1200             5       1503     1505
# 11   2013 1     1   1208     1158            10       1540     1502
# 12   2013 1     1   1248     1250            -2       1607     1607
# 13   2013 1     1   1306     1300             6       1622     1610
# ...

# %%
table(flights$carrier)
# Out:
#    9E    AA    AS    B6    DL    EV    F9    FL    HA    MQ    OO    UA    US
# 18460 32729   714 54635 48110 54173   685  3260   342 26397    32 58665 20536
#    VX    WN    YV
#  5162 12275   601

# %%
filter(flights,carrier %in% c('UA','AA','DL'))
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   554      600            -6         812      837
# 5      2013 1     1   554      558            -4         740      728
# 6      2013 1     1   558      600            -2         753      745
# 7      2013 1     1   558      600            -2         924      917
# 8      2013 1     1   558      600            -2         923      937
# 9      2013 1     1   559      600            -1         941      910
# 10     2013 1     1   559      600            -1         854      902
# 11     2013 1     1   602      610            -8         812      820
# 12     2013 1     1   606      610            -4         858      910
# ...

# %%
filter(flights,month %in% c(7,8,9))
# Out:
#       year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1     2013 7     1     1      2029           212       236      2359
# 2     2013 7     1     2      2359             3       344       344
# 3     2013 7     1    29      2245           104       151         1
# 4     2013 7     1    43      2130           193       322        14
# 5     2013 7     1    44      2150           174       300       100
# 6     2013 7     1    46      2051           235       304      2358
# 7     2013 7     1    48      2001           287       308      2305
# 8     2013 7     1    58      2155           183       335        43
# 9     2013 7     1   100      2146           194       327        30
# 10    2013 7     1   100      2245           135       337       135
# 11    2013 7     1   107      2245           142       158      2359
# 12    2013 7     1   111      2359            72       448       340
# ...

# %%
filter(flights,arr_delay>=2&dep_delay==0)
# Out:
#      year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1    2013 1     1    600      600           0          837      825
# 2    2013 1     1    635      635           0         1028      940
# 3    2013 1     1    739      739           0         1104     1038
# 4    2013 1     1    745      745           0         1135     1125
# 5    2013 1     1    800      800           0         1022     1014
# 6    2013 1     1    805      805           0         1015     1005
# 7    2013 1     1    810      810           0         1048     1037
# 8    2013 1     1    823      823           0         1151     1135
# 9    2013 1     1    830      830           0         1018     1015
# 10   2013 1     1    835      835           0         1210     1150
# 11   2013 1     1    900      900           0         1211     1203
# 12   2013 1     1    905      905           0         1309     1229
# 13   2013 1     1    908      908           0         1228     1219
# ...

# %%
filter(flights,arr_delay>=2,air_time>30)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   554      558            -4         740      728
# 5      2013 1     1   555      600            -5         913      854
# 6      2013 1     1   558      600            -2         753      745
# 7      2013 1     1   558      600            -2         924      917
# 8      2013 1     1   559      600            -1         941      910
# 9      2013 1     1   600      600             0         837      825
# 10     2013 1     1   602      605            -3         821      805
# 11     2013 1     1   608      600             8         807      735
# 12     2013 1     1   611      600            11         945      931
# ...

# %%
dim(filter(flights,is.na(dep_time)))[1]
# Out:
# [1] 8255

# %%
head(flights)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
arrange(flights,year,month,day)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %%
arrange(flights,desc(dep_delay)) # Descending Order of arranging
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013  1     9   641      900           1301      1242     1530
# 2      2013  6    15  1432     1935           1137      1607     2120
# 3      2013  1    10  1121     1635           1126      1239     1810
# 4      2013  9    20  1139     1845           1014      1457     2210
# 5      2013  7    22   845     1600           1005      1044     1815
# 6      2013  4    10  1100     1900            960      1342     2211
# 7      2013  3    17  2321      810            911       135     1020
# 8      2013  6    27   959     1900            899      1236     2226
# 9      2013  7    22  2257      759            898       121     1026
# 10     2013 12     5   756     1700            896      1058     2020
# 11     2013  5     3  1133     2055            878      1250     2215
# 12     2013  1     1   848     1835            853      1001     1950
# ...

# %%
test <- tibble(x=c(5,3,2,10,NA))
test
# Out:
#   x
# 1  5
# 2  3
# 3  2
# 4 10
# 5 NA

# %%
arrange(test,x)
# Out:
#   x
# 1  2
# 2  3
# 3  5
# 4 10
# 5 NA

# %%
arrange(test,desc(x))
# Out:
#   x
# 1 10
# 2  5
# 3  3
# 4  2
# 5 NA

# %%
arrange(flights,desc(is.na(dep_time)),dep_time) %>% head()
arrange(flights,desc(is.na(dep_time)),dep_time) %>% tail()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   NA       1630           NA        NA       1815
# 2 2013 1     1   NA       1935           NA        NA       2240
# 3 2013 1     1   NA       1500           NA        NA       1825
# 4 2013 1     1   NA        600           NA        NA        901
# 5 2013 1     2   NA       1540           NA        NA       1747
# 6 2013 1     2   NA       1620           NA        NA       1746
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 NA        EV      4308   N18120  EWR    RDU  NA        416     16   30
# 2 NA        AA       791   N3EHAA  LGA    DFW  NA       1389     19   35
# 3 NA        AA      1925   N3EVAA  LGA    MIA  NA       1096     15    0
# 4 NA        B6       125   N618JB  JFK    FLL  NA       1069      6    0
# 5 NA        EV      4352   N10575  EWR    CVG  NA        569     15   40
# ...

# %%
names(flights)
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %%
arrange(flights,desc(dep_delay)) %>% head()
arrange(flights,dep_delay) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1      9   641      900           1301      1242     1530
# 2 2013 6     15  1432     1935           1137      1607     2120
# 3 2013 1     10  1121     1635           1126      1239     1810
# 4 2013 9     20  1139     1845           1014      1457     2210
# 5 2013 7     22   845     1600           1005      1044     1815
# 6 2013 4     10  1100     1900            960      1342     2211
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 1272      HA        51   N384HA  JFK    HNL  640      4983      9    0
# 2 1127      MQ      3535   N504MQ  JFK    CMH   74       483     19   35
# 3 1109      MQ      3695   N517MQ  EWR    ORD  111       719     16   35
# 4 1007      AA       177   N338AA  JFK    SFO  354      2586     18   45
# 5  989      MQ      3075   N665MQ  JFK    CVG   96       589     16    0
# ...

# %%
arrange(flights,desc(distance/air_time)) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013  5    25  1709     1700            9        1923     1937
# 2 2013  7     2  1558     1513           45        1745     1719
# 3 2013  5    13  2040     2025           15        2225     2226
# 4 2013  3    23  1914     1910            4        2045     2043
# 5 2013  1    12  1559     1600           -1        1849     1917
# 6 2013 11    17   650      655           -5        1059     1150
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -14       DL      1499   N666DN  LGA    ATL   65       762     17    0
# 2  26       EV      4667   N17196  EWR    MSP   93      1008     15   13
# 3  -1       EV      4292   N14568  EWR    GSP   55       594     20   25
# 4   2       EV      3805   N12567  EWR    BNA   70       748     19   10
# 5 -28       DL      1902   N956DL  LGA    PBI  105      1035     16    0
# ...

# %%
# Farthest
arrange(flights,desc(distance)) %>% head()
# Shortest
arrange(flights,distance) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1    857     900            -3        1516     1530
# 2 2013 1     2    909     900             9        1525     1530
# 3 2013 1     3    914     900            14        1504     1530
# 4 2013 1     4    900     900             0        1516     1530
# 5 2013 1     5    858     900            -2        1519     1530
# 6 2013 1     6   1019     900            79        1558     1530
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -14       HA      51     N380HA  JFK    HNL  659      4983     9    0
# 2  -5       HA      51     N380HA  JFK    HNL  638      4983     9    0
# 3 -26       HA      51     N380HA  JFK    HNL  616      4983     9    0
# 4 -14       HA      51     N384HA  JFK    HNL  639      4983     9    0
# 5 -11       HA      51     N381HA  JFK    HNL  635      4983     9    0
# ...

# %% [markdown]
# ## Operations on columns (select, mutate)

# %%
select(flights,year,month,day) %>% tail()
# Out:
#   year month day
# 1 2013 9     30
# 2 2013 9     30
# 3 2013 9     30
# 4 2013 9     30
# 5 2013 9     30
# 6 2013 9     30

# %%
select(flights,year:day) %>% tail()
# Out:
#   year month day
# 1 2013 9     30
# 2 2013 9     30
# 3 2013 9     30
# 4 2013 9     30
# 5 2013 9     30
# 6 2013 9     30

# %%
select(flights,-(year:day)) # All columns except the ones between year and day inclusive
# Out:
#        dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay
# 1      517      515             2         830      819            11
# 2      533      529             4         850      830            20
# 3      542      540             2         923      850            33
# 4      544      545            -1        1004     1022           -18
# 5      554      600            -6         812      837           -25
# 6      554      558            -4         740      728            12
# 7      555      600            -5         913      854            19
# 8      557      600            -3         709      723           -14
# 9      557      600            -3         838      846            -8
# 10     558      600            -2         753      745             8
# 11     558      600            -2         849      851            -2
# 12     558      600            -2         853      856            -3
# 13     558      600            -2         924      917             7
# ...

# %%
names(flights)
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %%
select(flights,starts_with('d')) %>% head()
# Out:
#   day dep_time dep_delay dest distance
# 1 1   517       2        IAH  1400
# 2 1   533       4        IAH  1416
# 3 1   542       2        MIA  1089
# 4 1   544      -1        BQN  1576
# 5 1   554      -6        ATL   762
# 6 1   554      -4        ORD   719

# %%
select(flights,ends_with('y')) %>% head()
# Out:
#   day dep_delay arr_delay
# 1 1    2         11
# 2 1    4         20
# 3 1    2         33
# 4 1   -1        -18
# 5 1   -6        -25
# 6 1   -4         12

# %%
select(flights,contains('time')) %>% tail()
# Out:
#   dep_time sched_dep_time arr_time sched_arr_time air_time time_hour
# 1 NA       1842           NA       2019           NA       2013-09-30 18:00:00
# 2 NA       1455           NA       1634           NA       2013-09-30 14:00:00
# 3 NA       2200           NA       2312           NA       2013-09-30 22:00:00
# 4 NA       1210           NA       1330           NA       2013-09-30 12:00:00
# 5 NA       1159           NA       1344           NA       2013-09-30 11:00:00
# 6 NA        840           NA       1020           NA       2013-09-30 08:00:00

# %%
select(flights,distance,air_time) %>% tail()
# Out:
#   distance air_time
# 1 764      NA
# 2 213      NA
# 3 198      NA
# 4 764      NA
# 5 419      NA
# 6 431      NA

# %%
select(flights,distance,air_time,everything()) %>% tail()
# Out:
#   distance air_time year month day dep_time sched_dep_time dep_delay arr_time
# 1 764      NA       2013 9     30  NA       1842           NA        NA
# 2 213      NA       2013 9     30  NA       1455           NA        NA
# 3 198      NA       2013 9     30  NA       2200           NA        NA
# 4 764      NA       2013 9     30  NA       1210           NA        NA
# 5 419      NA       2013 9     30  NA       1159           NA        NA
# 6 431      NA       2013 9     30  NA        840           NA        NA
#   sched_arr_time arr_delay carrier flight tailnum origin dest hour minute
# 1 2019           NA        EV      5274   N740EV  LGA    BNA  18   42
# 2 1634           NA        9E      3393   NA      JFK    DCA  14   55
# 3 2312           NA        9E      3525   NA      LGA    SYR  22    0
# 4 1330           NA        MQ      3461   N535MQ  LGA    BNA  12   10
# 5 1344           NA        MQ      3572   N511MQ  LGA    CLE  11   59
# ...

# %%
flights
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %%
select(flights,dep_time,dep_delay,arr_time,arr_delay) %>% head()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 517       2         830      11
# 2 533       4         850      20
# 3 542       2         923      33
# 4 544      -1        1004     -18
# 5 554      -6         812     -25
# 6 554      -4         740      12

# %%
select(flights,starts_with('dep'),starts_with('arr')) %>% tail()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 NA       NA        NA       NA
# 2 NA       NA        NA       NA
# 3 NA       NA        NA       NA
# 4 NA       NA        NA       NA
# 5 NA       NA        NA       NA
# 6 NA       NA        NA       NA

# %%
select(flights,matches('^(dep|arr)_(time|delay)$')) %>% tail()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 NA       NA        NA       NA
# 2 NA       NA        NA       NA
# 3 NA       NA        NA       NA
# 4 NA       NA        NA       NA
# 5 NA       NA        NA       NA
# 6 NA       NA        NA       NA

# %%
select(flights,dep_time,dep_time,dep_time) %>% tail()
# Out:
#   dep_time
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
vars <- c("year", "month", "day", "dep_delay", "arr_delay")
df <- select(flights,any_of(vars))
filter(df,dep_delay==0,arr_delay==0) %>% tail()
# Out:
#   year month day dep_delay arr_delay
# 1 2013 9     24  0         0
# 2 2013 9     27  0         0
# 3 2013 9     27  0         0
# 4 2013 9     30  0         0
# 5 2013 9     30  0         0
# 6 2013 9     30  0         0

# %%
select(flights,contains("TIME", ignore.case=FALSE)) %>% tail()
# Out:
#
# 1
# 2
# 3
# 4
# 5
# 6

# %%
flights_sml <- select(flights,
                     year:day,
                     ends_with('delay'),
                     distance,
                     air_time)
mutate(flights_sml,
      gain=dep_delay-arr_delay,
      speed=distance/air_time*60,
      hours=air_time/60,
      gain_per_hour=gain/hours) %>% head()
# Out:
#   year month day dep_delay arr_delay distance air_time gain speed    hours
# 1 2013 1     1    2         11       1400     227       -9  370.0441 3.783333
# 2 2013 1     1    4         20       1416     227      -16  374.2731 3.783333
# 3 2013 1     1    2         33       1089     160      -31  408.3750 2.666667
# 4 2013 1     1   -1        -18       1576     183       17  516.7213 3.050000
# 5 2013 1     1   -6        -25        762     116       19  394.1379 1.933333
# 6 2013 1     1   -4         12        719     150      -16  287.6000 2.500000
#   gain_per_hour
# 1  -2.378855
# 2  -4.229075
# 3 -11.625000
# 4   5.573770
# 5   9.827586
# 6  -6.400000

# %%
transmute(flights_sml,
           gain=dep_delay-arr_delay,
           speed=distance/air_time*60) %>% head()
# Out:
#   gain speed
# 1  -9  370.0441
# 2 -16  374.2731
# 3 -31  408.3750
# 4  17  516.7213
# 5  19  394.1379
# 6 -16  287.6000

# %%
exo <- select(flights,
             c("dep_time", "sched_dep_time", "arr_time", "air_time"))
exo %>% head()
# Out:
#   dep_time sched_dep_time arr_time air_time
# 1 517      515             830     227
# 2 533      529             850     227
# 3 542      540             923     160
# 4 544      545            1004     183
# 5 554      600             812     116
# 6 554      558             740     150

# %%
mutate(exo,
      h1=dep_time%/%100,
      m1=dep_time%%100,
      h2=sched_dep_time%/%100,
      m2=sched_dep_time%%100) %>% head()
# Out:
#   dep_time sched_dep_time arr_time air_time h1 m1 h2 m2
# 1 517      515             830     227      5  17 5  15
# 2 533      529             850     227      5  33 5  29
# 3 542      540             923     160      5  42 5  40
# 4 544      545            1004     183      5  44 5  45
# 5 554      600             812     116      5  54 6   0
# 6 554      558             740     150      5  54 5  58

# %%
mutate(exo,
      air_time,
      diff=arr_time-dep_time) %>% head()
# Out:
#   dep_time sched_dep_time arr_time air_time diff
# 1 517      515             830     227      313
# 2 533      529             850     227      317
# 3 542      540             923     160      381
# 4 544      545            1004     183      460
# 5 554      600             812     116      258
# 6 554      558             740     150      186

# %%
glimpse(exo)
# Out:
# Rows: 336,776
# Columns: 4
# $ dep_time       <int> 517, 533, 542, 544, 554, 554, 555, 557, 557, 558, 558, ~
# $ sched_dep_time <int> 515, 529, 540, 545, 600, 558, 600, 600, 600, 600, 600, ~
# $ arr_time       <int> 830, 850, 923, 1004, 812, 740, 913, 709, 838, 753, 849,~
# $ air_time       <dbl> 227, 227, 160, 183, 116, 150, 158, 53, 140, 138, 149, 1~

# %%
by_day <- group_by(flights,year,month,day)
summarise(by_day,delay=mean(dep_delay,na.rm=TRUE)) %>% tail()
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#   year month day delay
# 1 2013 12    26  14.417204
# 2 2013 12    27  10.937630
# 3 2013 12    28   7.981550
# 4 2013 12    29  22.309551
# 5 2013 12    30  10.698113
# 6 2013 12    31   6.996053

# %%
by_day <- group_by(flights,year,month,day)
head(by_day)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
head(summarise(by_day, delay=mean(dep_delay,na.rm=TRUE)))
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#   year month day delay
# 1 2013 1     1   11.548926
# 2 2013 1     2   13.858824
# 3 2013 1     3   10.987832
# 4 2013 1     4    8.951595
# 5 2013 1     5    5.732218
# 6 2013 1     6    7.148014

# %%
day1 <- filter(flights,year==2013,month==1,day==1)
head(day1)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
mean(day1$dep_delay,na.rm=TRUE)
# Out:
# [1] 11.54893

# %%
by_dest <- group_by(flights,dest)
delay <- summarise(by_dest,
                  count=n(),
                  dist=mean(distance,na.rm=TRUE),
                  delay=mean(arr_delay,na.rm=TRUE))
tail(delay)
delay <- filter(delay,count>20,dest!="NHL")
# Out:
#   dest count dist      delay
# 1 SYR  1761   205.9216  8.903925
# 2 TPA  7466  1003.9356  7.408525
# 3 TUL   315  1215.0000 33.659864
# 4 TVC   101   652.3861 12.968421
# 5 TYS   631   638.8098 24.069204
# 6 XNA  1036  1142.5058  7.465726

# %%
ggplot(data=delay,mapping=aes(x=dist,y=delay)) +
    geom_point(aes(size=count),alpha=1/3) +
    geom_smooth(se=FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# More compact than the code above 
delay <- flights %>%
    group_by(dest) %>%
    summarise(
        count=n(),
        dist=mean(distance,na.rm=TRUE),
        delay=mean(arr_delay,na.rm=TRUE)
    ) %>%
    filter(count > 20,dest!="NHL")

# %%
delay %>% tail
# Out:
#   dest count dist      delay
# 1 SYR  1761   205.9216  8.903925
# 2 TPA  7466  1003.9356  7.408525
# 3 TUL   315  1215.0000 33.659864
# 4 TVC   101   652.3861 12.968421
# 5 TYS   631   638.8098 24.069204
# 6 XNA  1036  1142.5058  7.465726

# %%
flights %>%
    group_by(year,month,day) %>%
    summarise(
        count=n(),
        mean=mean(dep_delay)
    )
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#     year month day count mean
# 1   2013 1      1  842   NA
# 2   2013 1      2  943   NA
# 3   2013 1      3  914   NA
# 4   2013 1      4  915   NA
# 5   2013 1      5  720   NA
# 6   2013 1      6  832   NA
# 7   2013 1      7  933   NA
# 8   2013 1      8  899   NA
# 9   2013 1      9  902   NA
# 10  2013 1     10  932   NA
# 11  2013 1     11  930   NA
# 12  2013 1     12  690   NA
# 13  2013 1     13  828   NA
# 14  2013 1     14  928   NA
# 15  2013 1     15  894   NA
# 16  2013 1     16  901   NA
# 17  2013 1     17  927   NA
# 18  2013 1     18  924   NA
# 19  2013 1     19  674   NA
# 20  2013 1     20  786   NA
# 21  2013 1     21  912   NA
# 22  2013 1     22  890   NA
# 23  2013 1     23  897   NA
# 24  2013 1     24  925   NA
# 25  2013 1     25  922   NA
# 26  2013 1     26  680   NA
# 27  2013 1     27  823   NA
# 28  2013 1     28  923   NA
# ...

# %%
not_cancelled <- flights %>%
    filter(!is.na(dep_delay),!is.na(arr_delay))

# %%
not_cancelled %>%
    group_by(year,month,day) %>%
    summarise(count=n(),mean=mean(dep_delay))
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#     year month day count mean
# 1   2013 1      1  831   11.435620
# 2   2013 1      2  928   13.677802
# 3   2013 1      3  900   10.907778
# 4   2013 1      4  908    8.965859
# 5   2013 1      5  717    5.732218
# 6   2013 1      6  829    7.145959
# 7   2013 1      7  930    5.417204
# 8   2013 1      8  892    2.558296
# 9   2013 1      9  893    2.301232
# 10  2013 1     10  929    2.844995
# 11  2013 1     11  917    2.833152
# 12  2013 1     12  681    1.593245
# 13  2013 1     13  807   19.619579
# 14  2013 1     14  923    2.798483
# 15  2013 1     15  881    0.123723
# 16  2013 1     16  853   24.454865
# 17  2013 1     17  915    7.685246
# 18  2013 1     18  910    6.768132
# 19  2013 1     19  671    3.362146
# 20  2013 1     20  781    6.804097
# 21  2013 1     21  902    7.839246
# 22  2013 1     22  885   12.499435
# 23  2013 1     23  888   10.610360
# ...

# %%
delays <- not_cancelled %>%
    group_by(tailnum) %>%
    summarise(delay=mean(arr_delay),n=n())

ggplot(data=delays,mapping=aes(x=delay)) +
    geom_freqpoly(binwidht=10,size=1.1)
# Out:
# Warning message:
# "Ignoring unknown parameters: binwidht"
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(data=delays,mapping=aes(x=n,y=delay)) +
    geom_point(alpha=1/10)
# Out:
# plot without title

# %%
delays %>%
    filter(n>25) %>%
    ggplot(mapping=aes(x=n,y=delay)) +
        geom_point(alpha=1/10)
# Out:
# plot without title

# %%
library(Lahman)
batting <- as_tibble(Lahman::Batting)
dim(batting)
# Out:
# [1] 108789     22

# %%
batters <- batting %>%
    group_by(playerID) %>%
    summarise(
        ba = sum(H,na.rm=TRUE)/sum(AB,na.rm=TRUE),
        ab = sum(AB,na.rm=TRUE)
    ) 
batters %>%
    filter(ab > 100) %>%
    ggplot(mapping=aes(x=ab,y=ba)) +
        geom_point() +
        geom_smooth(se=FALSE)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
batters %>%
    arrange(desc(ba)) %>% head
# Out:
#   playerID  ba ab
# 1 abramge01 1  1
# 2 alanirj01 1  1
# 3 alberan01 1  1
# 4 banisje01 1  1
# 5 bartocl01 1  1
# 6 bassdo01  1  1
